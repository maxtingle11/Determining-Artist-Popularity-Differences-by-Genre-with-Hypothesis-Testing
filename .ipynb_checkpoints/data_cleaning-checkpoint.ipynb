# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
#Creating artist_codes dataframe
artists = pd.read_csv('Data/spotify_artists.csv')
artists = artists.drop(["Unnamed: 0", "artist_uri"], axis=1)

# %%
#Take brackets out of artist_genres column string data
artists['artist_genres'] = artists['artist_genres'].str[1:-1]

# %%
#Take quotes out of artist_genres column string data
artists['artist_genres'] = artists['artist_genres'].str.replace("'", "")

# %%
#Take spaces out of artist_genres column string data
artists['artist_genres'] = artists['artist_genres'].str.replace(" ", "")

# %%
#Take dashes out of artist_genres column string data
artists['artist_genres'] = artists['artist_genres'].str.replace("-", "")

# %%
#Replace empty genre data points with NaNs
artists['artist_genres'] = artists['artist_genres'].apply(lambda y: np.nan if y=='' else y)

# %%
#Drop rows with NaN genre data
artists = artists.dropna(subset=['artist_genres'])

# %%
#Drop rows with NaN artist_name data
artists = artists.dropna(subset=['artist_name'])

# %%
#Drop rows with NaN artist_followers data
artists = artists.dropna(subset=['artist_followers'])

# %%
print(artists.info())
artists.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130960 entries, 0 to 314797
# Data columns (total 5 columns):
# artist_id            130960 non-null object
# artist_name          130960 non-null object
# artist_genres        130960 non-null object
# artist_followers     130960 non-null float64
# artist_popularity    130960 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 6.0+ MB
# None
#                  artist_id                 artist_name  \
# 0   4tN3rZ7cChj4Wns2Wt2Nj6                        2 AM
# 2   3LsQKoRgMc8VEkQn66jfAQ                        2:54
# 12  6bMul6rmRS03x38tWKYifO                         883
# 13  0Qh5UGy4Y1hrZlClkIP7oG                         3-2
# 15  51kPCmCJ7rXClxKDc2r4RA                      July 7
# 18  733SPLVnEyXs6GxUEnJ7bx                        11/5
# 19  6soPpJHlCtN6SY8pWlfbC6                         -M-
# 21  4EbEUPsgjjmNsKjigP3R4u                       -ness
# 23  6bdOuFTmkGliFvCkdpH49Z  :Of The Wand And The Moon:
# 24  3TTbkikkCAbUg2j5i9UrTV                  :Wumpscut:
#
#                                         artist_genres  artist_followers  \
# 0                         antiviralpop,kpop,minecraft            2075.0
# 2                                        metropopolis           10158.0
# 12  classicitalianpop,europop,italianarenapop,ital...          389768.0
# 13                            deepgfunk,dirtytexasrap              62.0
# 15                                           trapsoul            3119.0
# 18                                        gfunk,hyphy           14489.0
# 19                  chanson,frenchindiepop,frenchrock          189142.0
# 21                                           hopebeat             936.0
# 23  martialindustrial,medievalfolk,neoclassical,ne...           12728.0
# 24  aggrotech,darkwave,ebm,electroindustrial,indus...           29931.0
#
#     artist_popularity
# 0                  41
# 2                  19
# 12                 59
# 13                 19
# 15                 34
# 18                 29
# 19                 60
# 21                 15
# 23                 31
# 24                 36

# %%
#Creating list of parent genres
#Referencing: https://www.blisshq.com/music-library-management-blog/2011/01/25/fundamental-music-genre-list/
parent_genres = ['blues', 'children', 'classical', 'country',
                 'edm', 'electronic', 'folk', 'funk', 'hiphop', 
                 'indie', 'jazz', 'latin', 'pop', 'r&b', 'rap', 
                 'reggae', 'rock', 'soul', 'soundtrack'
                ]

len(parent_genres)
# Out:
# 19

# %%
# Creating new columns for each unique genre and assign NaN values
for genre in parent_genres:
    artists[genre] = np.nan

# %%
# Assigning True Boolean value to parent genre columns 
# If subgenre appears in artist_genres column
for genre in parent_genres:
    artists[genre] = artists.artist_genres.apply(lambda x: genre in x)

# %%
print(artists.info())
artists.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130960 entries, 0 to 314797
# Data columns (total 24 columns):
# artist_id            130960 non-null object
# artist_name          130960 non-null object
# artist_genres        130960 non-null object
# artist_followers     130960 non-null float64
# artist_popularity    130960 non-null int64
# blues                130960 non-null bool
# children             130960 non-null bool
# classical            130960 non-null bool
# country              130960 non-null bool
# edm                  130960 non-null bool
# electronic           130960 non-null bool
# folk                 130960 non-null bool
# funk                 130960 non-null bool
# hiphop               130960 non-null bool
# indie                130960 non-null bool
# jazz                 130960 non-null bool
# latin                130960 non-null bool
# pop                  130960 non-null bool
# r&b                  130960 non-null bool
# rap                  130960 non-null bool
# reggae               130960 non-null bool
# rock                 130960 non-null bool
# soul                 130960 non-null bool
# soundtrack           130960 non-null bool
# dtypes: bool(19), float64(1), int64(1), object(3)
# memory usage: 8.4+ MB
# None
#                  artist_id                 artist_name  \
# 0   4tN3rZ7cChj4Wns2Wt2Nj6                        2 AM
# 2   3LsQKoRgMc8VEkQn66jfAQ                        2:54
# 12  6bMul6rmRS03x38tWKYifO                         883
# 13  0Qh5UGy4Y1hrZlClkIP7oG                         3-2
# 15  51kPCmCJ7rXClxKDc2r4RA                      July 7
# 18  733SPLVnEyXs6GxUEnJ7bx                        11/5
# 19  6soPpJHlCtN6SY8pWlfbC6                         -M-
# 21  4EbEUPsgjjmNsKjigP3R4u                       -ness
# 23  6bdOuFTmkGliFvCkdpH49Z  :Of The Wand And The Moon:
# 24  3TTbkikkCAbUg2j5i9UrTV                  :Wumpscut:
#
#                                         artist_genres  artist_followers  \
# 0                         antiviralpop,kpop,minecraft            2075.0
# 2                                        metropopolis           10158.0
# 12  classicitalianpop,europop,italianarenapop,ital...          389768.0
# 13                            deepgfunk,dirtytexasrap              62.0
# 15                                           trapsoul            3119.0
# 18                                        gfunk,hyphy           14489.0
# 19                  chanson,frenchindiepop,frenchrock          189142.0
# 21                                           hopebeat             936.0
# 23  martialindustrial,medievalfolk,neoclassical,ne...           12728.0
# 24  aggrotech,darkwave,ebm,electroindustrial,indus...           29931.0
#
#     artist_popularity  blues  children  classical  country    edm  ...  indie  \
# 0                  41  False     False      False    False  False  ...  False
# 2                  19  False     False      False    False  False  ...  False
# 12                 59  False     False      False    False  False  ...  False
# 13                 19  False     False      False    False  False  ...  False
# 15                 34  False     False      False    False  False  ...  False
# 18                 29  False     False      False    False  False  ...  False
# 19                 60  False     False      False    False  False  ...   True
# 21                 15  False     False      False    False  False  ...  False
# 23                 31  False     False       True    False  False  ...  False
# 24                 36  False     False      False    False  False  ...  False
#
#      jazz  latin    pop    r&b    rap  reggae   rock   soul  soundtrack
# 0   False  False   True  False  False   False  False  False       False
# 2   False  False   True  False  False   False  False  False       False
# 12  False  False   True  False  False   False  False  False       False
# 13  False  False  False  False   True   False  False  False       False
# 15  False  False  False  False   True   False  False   True       False
# 18  False  False  False  False  False   False  False  False       False
# 19  False  False   True  False  False   False   True  False       False
# 21  False  False  False  False  False   False  False  False       False
# 23  False  False  False  False  False   False  False  False       False
# 24  False  False  False  False  False   False   True  False       False
#
# [10 rows x 24 columns]

# %%
#Create column that counts number of genres per row that are True
artists['genre_count'] = artists.iloc[:,5:24].apply(lambda s: (s > 0).sum(), axis=1)

# %%
#Take out rows with more than one parent genre
filtered_artists = artists[(artists['genre_count']==1)]

# %%
print(filtered_artists.info())
filtered_artists.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53244 entries, 0 to 314797
# Data columns (total 25 columns):
# artist_id            53244 non-null object
# artist_name          53244 non-null object
# artist_genres        53244 non-null object
# artist_followers     53244 non-null float64
# artist_popularity    53244 non-null int64
# blues                53244 non-null bool
# children             53244 non-null bool
# classical            53244 non-null bool
# country              53244 non-null bool
# edm                  53244 non-null bool
# electronic           53244 non-null bool
# folk                 53244 non-null bool
# funk                 53244 non-null bool
# hiphop               53244 non-null bool
# indie                53244 non-null bool
# jazz                 53244 non-null bool
# latin                53244 non-null bool
# pop                  53244 non-null bool
# r&b                  53244 non-null bool
# rap                  53244 non-null bool
# reggae               53244 non-null bool
# rock                 53244 non-null bool
# soul                 53244 non-null bool
# soundtrack           53244 non-null bool
# genre_count          53244 non-null int64
# dtypes: bool(19), float64(1), int64(2), object(3)
# memory usage: 3.8+ MB
# None
#                  artist_id          artist_name  \
# 0   4tN3rZ7cChj4Wns2Wt2Nj6                 2 AM
# 2   3LsQKoRgMc8VEkQn66jfAQ                 2:54
# 18  733SPLVnEyXs6GxUEnJ7bx                 11/5
# 24  3TTbkikkCAbUg2j5i9UrTV           :Wumpscut:
# 30  1h2OVSKRdJHnVqyCKqCLkf            ?uestlove
# 40  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 49  2McJOiKebPtBGqyEYyZQFN             [:SITD:]
# 56  16LvTqpD4wlfFb4EBcW0x3         [dunkelbunt]
# 64  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 65  0PEqo7RkX5wkaYwlT6hINn       *repeat repeat
#
#                                         artist_genres  artist_followers  \
# 0                         antiviralpop,kpop,minecraft            2075.0
# 2                                        metropopolis           10158.0
# 18                                        gfunk,hyphy           14489.0
# 24  aggrotech,darkwave,ebm,electroindustrial,indus...           29931.0
# 30                                          phillyrap           16178.0
# 40                                   comedyrock,comic          423423.0
# 49  aggrotech,darkwave,ebm,electroindustrial,futur...           13580.0
# 56                    balkanbrass,electroswing,nujazz           16406.0
# 64                       boyband,dancepop,europop,pop         1076991.0
# 65                                     nashvilleindie            5270.0
#
#     artist_popularity  blues  children  classical  country    edm  ...   jazz  \
# 0                  41  False     False      False    False  False  ...  False
# 2                  19  False     False      False    False  False  ...  False
# 18                 29  False     False      False    False  False  ...  False
# 24                 36  False     False      False    False  False  ...  False
# 30                 34  False     False      False    False  False  ...  False
# 40                 60  False     False      False    False  False  ...  False
# 49                 36  False     False      False    False  False  ...  False
# 56                 43  False     False      False    False  False  ...   True
# 64                 71  False     False      False    False  False  ...  False
# 65                 34  False     False      False    False  False  ...  False
#
#     latin    pop    r&b    rap  reggae   rock   soul  soundtrack  genre_count
# 0   False   True  False  False   False  False  False       False            1
# 2   False   True  False  False   False  False  False       False            1
# 18  False  False  False  False   False  False  False       False            1
# 24  False  False  False  False   False   True  False       False            1
# 30  False  False  False   True   False  False  False       False            1
# 40  False  False  False  False   False   True  False       False            1
# 49  False   True  False  False   False  False  False       False            1
# 56  False  False  False  False   False  False  False       False            1
# 64  False   True  False  False   False  False  False       False            1
# 65  False  False  False  False   False  False  False       False            1
#
# [10 rows x 25 columns]

# %%
# Exporting DataFrame
filtered_artists.to_csv('Data/spotify_artists_cleaned.csv', index=False)
